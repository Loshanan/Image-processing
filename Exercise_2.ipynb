# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
f = cv.imread(r'spider.png', cv.IMREAD_GRAYSCALE)
assert f is not None

gamma = 2
t = np.array([(p/255)**gamma*255 for p in range (0,256)]).astype(np.uint8)
g = cv.LUT(f, t)

fig, ax = plt.subplots()
ax.plot(t)

fig, ax = plt.subplots(1, 2, figsize=(8,8))
ax[0].imshow(f, cmap='gray', vmin=0, vmax=255)
ax[0].set_title('input')
ax[1].imshow(g, cmap='gray', vmin=0, vmax=255)
ax[1].set_title('output')
plt.show()

# %%
f = cv.imread(r'spider.png', cv.IMREAD_GRAYSCALE)
assert f is not None

t1 = np.linspace(0, 100, 50)
t2 = np.linspace(100, 255, 150)
t3 = np.linspace(255, 255, 56)

t = np.concatenate((t1, t2,t3), axis=0).astype(np.uint8)
fig, ax = plt.subplots()
ax.plot(t)
ax.set_aspect('equal')
assert len(t)==256

g = cv.LUT(f, t)

fig, ax = plt.subplots(1, 2, figsize=(8,8))
ax[0].imshow(f, cmap='gray', vmin=0, vmax=255)
ax[0].set_title('input')
ax[1].imshow(g, cmap='gray', vmin=0, vmax=255)
ax[1].set_title('output')
plt.show()

# %%
f = cv.imread(r'shells.tif', cv.IMREAD_GRAYSCALE)
assert f is not None

hist_f = cv.calcHist([f], [0], None, [256], [0,256])
g = cv.equalizeHist(f)
hist_g = cv.calcHist([g], [0], None, [256], [0,256])

fig, ax = plt.subplots(2, 2, figsize=(10,8))

ax[0,0].plot(hist_f)
ax[0,0].set_title('hist_not_equalized')

ax[1,0].imshow(f, cmap='gray', vmin=0, vmax=255)
ax[1,0].set_title('image_not_equalized')

ax[0,1].plot(hist_g)
ax[0,1].set_title('hist_equalized')

ax[1,1].imshow(g, cmap='gray', vmin=0, vmax=255)
ax[1,1].set_title('image_equalized')

plt.show()

# %%
img = cv.imread(r'zion_pass.jpg', cv.IMREAD_COLOR)
assert f is not None

img = cv.cvtColor(img, cv.COLOR_BGR2RGB)

hsv = cv.cvtColor(img, cv.COLOR_RGB2HSV)

# hsv[:,:,1]+=50
hsv[:,:,1] = cv.add(hsv[:,:,1], 50)

sat = cv.cvtColor(hsv, cv.COLOR_HSV2RGB)

fig, ax = plt.subplots(1, 2, figsize=(10,10))
ax[0].imshow(img)
ax[0].set_title('origial image')
ax[1].imshow(sat)
ax[1].set_title('with enhanced saturation')
plt.show()

# %%
img = cv.imread(r'zion_pass.jpg', cv.IMREAD_COLOR)
assert img is not None

img = cv.cvtColor(img, cv.COLOR_BGR2RGB)

hsv = cv.cvtColor(img, cv.COLOR_RGB2HSV)
hsv[:,:,0] = cv.add(hsv[:,:,0], 25)
hue = cv.cvtColor(hsv, cv.COLOR_HSV2RGB)

fig, ax = plt.subplots(1, 2, figsize=(10,10))
ax[0].imshow(img)
ax[0].set_title('before')
ax[1].imshow(hue)
ax[1].set_title('after')
plt.show()
